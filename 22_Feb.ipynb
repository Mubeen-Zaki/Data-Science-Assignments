# %%
# 1) Code:
import requests
from bs4 import BeautifulSoup as bs

url = "https://www.youtube.com/@PW-Foundation/videos"
yt_html = bs(requests.get(url).content,'html.parser')
yt_html
# Out:
# <!DOCTYPE html>
# <html darker-dark-theme="" darker-dark-theme-deprecate="" lang="en-GB" style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" system-icons="" typography="" typography-spacing=""><head><script data-id="_gd" nonce="4H6Wwrb4kpB-B_l-hOxQkg">window.WIZ_global_data = {"MuJWjd":false,"nQyAE":{},"oxN3nb":{"1":false}};</script><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="ApvK67ociHgr2egd6c2ZjrfPuRs8BHcvSggogIOPQNH7GJ3cVlyJ1NOq/COCdj0+zxskqHt9HgLLETc8qqD+vwsAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2OTUxNjc5OTksImlzU3ViZG9tYWluIjp0cnVlfQ==" http-equiv="origin-trial"/><script nonce="4H6Wwrb4kpB-B_l-hOxQkg">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else{var k;for(k in a[0])ytcfg.d()[k]=a[0][k]}}};
# ...

# %%
pattern = r'<script nonce="[-\w]+">\n\s+var ytInitialData = (.+)'
script_data = re.search(pattern=pattern, string=yt_html.prettify())[1].replace(';', '')

json_data = json.loads(script_data)

videos_container = json_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents']

for video in videos_container[1:6]:
    video_id = video['richItemRenderer']['content']['videoRenderer']['videoId']
    video_url = f"https://www.youtube.com/watch?v={video_id}"
    print(video_url)
# Out:
# https://www.youtube.com/watch?v=3TL4-e3z7CA
# https://www.youtube.com/watch?v=U09HORTeaB8
# https://www.youtube.com/watch?v=eazPrtheE14
# https://www.youtube.com/watch?v=luqdZrYnFOM
# https://www.youtube.com/watch?v=YiBqvPi8Q1I

# %%
# 2) Code :
for video in videos_container[1:6]:
    thumb_url = video['richItemRenderer']['content']['videoRenderer']['thumbnail']['thumbnails'][0]['url']
    print(thumb_url)
# Out:
# https://i.ytimg.com/vi/3TL4-e3z7CA/hqdefault.jpg?sqp=-oaymwEiCKgBEF5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLBjrcbLxC2uulAf4GbN0YGqVuYfiw
# https://i.ytimg.com/vi/U09HORTeaB8/hqdefault.jpg?sqp=-oaymwEiCKgBEF5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLBvWohmuXp0juqKK3hvZzGPibuUuw
# https://i.ytimg.com/vi/eazPrtheE14/hqdefault.jpg?sqp=-oaymwEiCKgBEF5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLDbGgU3xB2IB-2QJG697BGxU4VATQ
# https://i.ytimg.com/vi/luqdZrYnFOM/hqdefault.jpg?sqp=-oaymwE8CKgBEF5IWvKriqkDLwgBFQAAAAAYASUAAMhCPQCAokN4AfABAfgB_gmAAtAFigIMCAAQARhVIE4oZTAP&rs=AOn4CLB2LZB8TtehrYEft0HAJm7WWgEs0Q
# https://i.ytimg.com/vi/YiBqvPi8Q1I/hqdefault.jpg?sqp=-oaymwEiCKgBEF5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLATczw52pHshYWiIBh5jS0JYI5QTQ

# %%
# 3) Code:
for video in videos_container[1:6]:
    thumb_url = video['richItemRenderer']['content']['videoRenderer']['title']['runs'][0]['text']
    print(thumb_url)
# Out:
# Launching FREE Batch for Class 10th @Class10th-UDAAN  | NEW Channel | Check Description.
# MEGA MOCK TEST Series is LIVE Now 🔴|| For Class-9th & 10th Students @free
# ALERT 🚨 : OLYMPIAD EXAM Registration Open for 2023-2024 | Step by Step Procedure | NSO | IMO | SOF
# Offer Ending Soon 🤯 | Only Few Hours Left | #SapneDekhneKiAzaadi 🔥
# Upto 35% Off On All PW Batches 🔥 | Only 1 Day Left 🤯 #SapneDekhneKiAzaadi

# %%
# 4) Code :
for video in videos_container[1:6]:
    views = video['richItemRenderer']['content']['videoRenderer']['viewCountText']['simpleText']
    print(views)
# Out:
# 90,263 views
# 51,875 views
# 21,774 views
# 17,386 views
# 13,154 views

# %%
# 5) Code :
for video in videos_container[1:6]:
    dates = video['richItemRenderer']['content']['videoRenderer']['publishedTimeText']['simpleText']
    print(dates)
# Out:
# 1 day ago
# 7 days ago
# 10 days ago
# 13 days ago
# 2 weeks ago
